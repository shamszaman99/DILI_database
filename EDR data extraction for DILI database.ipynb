# %%
import pandas as pd
import os, fnmatch
import xlrd
import difflib
import re

# %%
# find path to all the dm.xpt files given an application name
def find_dm_file (app_no):
    path = r"\\cdsesub1\evsprod\\"+app_no
    #print path

    result = []
    
    for root, dirs, files in os.walk(path):
        for direct in dirs:
            dirpath = os.path.join(root, direct)
            for name in os.listdir(dirpath):
                if fnmatch.fnmatch(name, "dm.xpt"):
                    result.append(os.path.join(root, direct, name))
         
        
    return result

# %%
list_of_dm_files = find_dm_file("BLA125504")

# %%
list_of_dm_files
# Out:
# ['\\\\cdsesub1\\evsprod\\\\BLA125504\\0000\\m5\\datasets\\ain457a2302\\tabulations\\sdtm\\dm.xpt',
#  '\\\\cdsesub1\\evsprod\\\\BLA125504\\0000\\m5\\datasets\\ain457a2303\\tabulations\\sdtm\\dm.xpt',
#  '\\\\cdsesub1\\evsprod\\\\BLA125504\\0000\\m5\\datasets\\ain457a2304\\tabulations\\sdtm\\dm.xpt',
#  '\\\\cdsesub1\\evsprod\\\\BLA125504\\0000\\m5\\datasets\\ain457a2307\\tabulations\\sdtm\\dm.xpt',
#  '\\\\cdsesub1\\evsprod\\\\BLA125504\\0000\\m5\\datasets\\ain457a2308\\tabulations\\sdtm\\dm.xpt',
#  '\\\\cdsesub1\\evsprod\\\\BLA125504\\0000\\m5\\datasets\\ain457a2309\\tabulations\\sdtm\\dm.xpt',
#  '\\\\cdsesub1\\evsprod\\\\BLA125504\\0060\\m5\\datasets\\ain457f2305\\tabulations\\sdtm\\dm.xpt',
#  '\\\\cdsesub1\\evsprod\\\\BLA125504\\0060\\m5\\datasets\\ain457f2306\\tabulations\\sdtm\\dm.xpt',
#  '\\\\cdsesub1\\evsprod\\\\BLA125504\\0060\\m5\\datasets\\ain457f2310\\tabulations\\sdtm\\dm.xpt',
#  '\\\\cdsesub1\\evsprod\\\\BLA125504\\0060\\m5\\datasets\\ain457f2312\\tabulations\\sdtm\\dm.xpt',
#  '\\\\cdsesub1\\evsprod\\\\BLA125504\\0122\\m5\\datasets\\ain457aus01\\tabulations\\sdtm\\dm.xpt']

# %%
biggest_dm_file = biggest_file(list_of_dm_files)

# %%
biggest_dm_file
# Out:
# '\\\\cdsesub1\\evsprod\\\\BLA761029\\0000\\m5\\datasets\\205ms301\\tabulations\\sdtm\\dm.xpt'

# %%
# Importing data into pandas data frame
df_dac = pd.read_sas(r'\\cdsesub1\\evsprod\\BLA761029\\0000\\m5\\datasets\\205ms201\\tabulations\\sdtm\\dm.xpt')

# %%
len(df_dac)
# Out:
# 621

# %%
data_elements_file =  pd.ExcelFile("C:\Users\Md.Shamsuzzaman\Documents\OCS\AIH\data_elements_ver2.xlsx")

# %%
# View the excel file's sheet names
data_elements_file.sheet_names
# Out:
# [u'Domains', u'LB', u'LB CodeList', u'DM', u'DM CodeList', u'Sheet1', u'AE']

# %%
# Load the xls file's Sheet1 as a dataframe
df = data_elements_file.parse('DM')
df.head()
# Out:
#   Variable Name                     Variable Label  Type  \
# 0      APPLICID             Application Identifier  Char
# 1       STUDYID                   Study Identifier  Char
# 2        DOMAIN                Domain Abbreviation  Char
# 3       USUBJID          Unique Subject Identifier  Char
# 4       RFSTDTC  Subject Reference Start Date/Time  Char
#
#   Controlled\nTerms, Codelist or Format              Role  \
# 0                                   NaN        Identifier
# 1                                   NaN        Identifier
# 2                                    DM        Identifier
# 3                                   NaN       Identifier
# 4                              ISO 8601  Record Qualifier
#
#                                          CDISC Notes Core         Remark
# 0                     Unique identifier for a study.  Req  User definded
# 1                     Unique identifier for a study.  Req            NaN
# 2         Two-character abbreviation for the domain.  Req            NaN
# 3  Identifier used to uniquely identify a subject...  Req            NaN
# 4  Reference Start Date/time for the subject in I...  Exp            NaN

# %%
# not collecting all the var at this moment - like ACTARM
df = df.iloc[:17,:]

# %%
# Data elements needs to be extracted from DM domains
DM_data_elements = list(df['Variable Name'])

# %%
# Not all 17 are present in Daclizumab DM domain. Hence, create an empty df with variables needed first

dm_df = pd.DataFrame(index = range(len(df_dac)), columns = DM_data_elements)

# %%
# find common col var 
common_var = list(set(DM_data_elements).intersection(list(df_dac)))

# %%
#how many are common
len(common_var)
# Out:
# 11

# %%
# find the vars which are missing in dm_df
list(set(DM_data_elements) - set(common_var))
# Out:
# [u'RFXENDTC', u'RFXSTDTC', u'DMDTC', u'DMDY', u'ETHNIC', u'APPLICID']

# %%
# fill up the dm_df with daclizumab data
dm_df['APPLICID'] = 'BLA761029'
dm_df[common_var] = df_dac[common_var]
# keep these empty
#dm_df['RFXSTDTC'] = df_dac['RFSTDTC']
#dm_df['RFXENDTC'] = df_dac['RFENDTC']

# %%
# Check the code values
set(list(dm_df['RACE']))
# Out:
# {'ASIAN', 'WHITE'}

# %%
# change the no reported value to other ------------- Lets not convert it
#dm_df.loc[dm_df['RACE'] =='NOT REPORTED DUE TO CONFIDENTIALITY REGULATIONS','RACE'] = 'OTHER'

# %%
dm_df.head()
# Out:
#     APPLICID   STUDYID DOMAIN           USUBJID           RFSTDTC  \
# 0  BLA761029  205MS201     DM  205MS201/100-001  2010-02-25T11:50
# 1  BLA761029  205MS201     DM  205MS201/100-002  2010-03-22T12:35
# 2  BLA761029  205MS201     DM  205MS201/100-003  2010-04-28T13:30
# 3  BLA761029  205MS201     DM  205MS201/100-004  2010-04-28T12:15
# 4  BLA761029  205MS201     DM  205MS201/101-001  2010-03-04T13:45
#
#             RFENDTC RFXSTDTC RFXENDTC   AGE SEX   RACE ETHNIC ARMCD  \
# 0  2011-01-25T11:30      NaN      NaN  36.0   F  ASIAN    NaN     1
# 1  2011-02-22T11:15      NaN      NaN  39.0   F  ASIAN    NaN     2
# 2  2011-04-05T14:20      NaN      NaN  42.0   M  ASIAN    NaN     2
# 3  2011-03-30T10:45      NaN      NaN  20.0   M  ASIAN    NaN     1
# 4  2011-02-05T12:00      NaN      NaN  24.0   F  ASIAN    NaN     2
#
#               ARM COUNTRY DMDTC DMDY
# 0  150 mg DAC HYP     IND   NaN  NaN
# 1  300 mg DAC HYP     IND   NaN  NaN
# 2  300 mg DAC HYP     IND   NaN  NaN
# 3  150 mg DAC HYP     IND   NaN  NaN
# 4  300 mg DAC HYP     IND   NaN  NaN

# %%
dm_df.to_csv("C:/Users/Md.Shamsuzzaman/Documents/OCS/AIH/Daclizumab/205ms201_DM2.csv", index = False)

# %%
len(dm_df)

# %%
dm1 = dm1.append(dm_df)
len(dm1)

# %%
dm1.to_csv("C:/Users/Md.Shamsuzzaman/Documents/OCS/AIH/Daclizumab/BLA761029_DM.csv", index = False)

# %%
# Importing Phase 3 lB data into pandas data frame
df_dac = pd.read_sas(r'\\cdsesub1\\evsprod\\BLA761029\\0014\\m5\\datasets\\205ms301\\tabulations\\sdtm\\lb.xpt')

# %%
df_dac.head()
# Out:
#     STUDYID DOMAIN           USUBJID  LBSEQ  LBREFID LBTESTCD  \
# 0  205MS301     LB  205MS301/100-004    1.0  L983846      ALP
# 1  205MS301     LB  205MS301/100-004    2.0  L983857      ALP
# 2  205MS301     LB  205MS301/100-004    3.0  Q437169      ALP
# 3  205MS301     LB  205MS301/100-004    4.0  R799628      ALP
# 4  205MS301     LB  205MS301/100-004    5.0  R799617      ALP
#
#                  LBTEST            LBCAT LBSCAT LBORRES  ...  LBSTAT LBREASND  \
# 0  Alkaline Phosphatase  BLOOD CHEMISTRY             52  ...
# 1  Alkaline Phosphatase  BLOOD CHEMISTRY             52  ...
# 2  Alkaline Phosphatase  BLOOD CHEMISTRY             51  ...
# 3  Alkaline Phosphatase  BLOOD CHEMISTRY             47  ...
# 4  Alkaline Phosphatase  BLOOD CHEMISTRY             51  ...
#
#      LBNAM LBBLFL  LBTOXGR VISITNUM      VISIT      EPOCH             LBDTC  \
# 0  CCLS_CO               0     10.0  SCREENING  SCREENING  2011-12-06T03:25
# 1  CCLS_CO      Y        0     20.0     WEEK 0  SCREENING  2011-12-20T13:29
# 2  CCLS_CO               0     30.0     WEEK 4  TREATMENT  2012-01-16T09:34
# 3  CCLS_CO               0     40.0     WEEK 8  TREATMENT  2012-02-17T10:08
# 4  CCLS_CO               0     50.0    WEEK 12  TREATMENT  2012-03-16T11:50
#
#    LBDY
# 0 -14.0
# 1   1.0
# 2  28.0
# 3  60.0
# 4  88.0
#
# [5 rows x 29 columns]

# %%
# Load the xls file's Sheet1 as a dataframe
df = data_elements_file.parse('LB')
df.head()
# Out:
#   Variable Name             Variable Label  Type  \
# 0      APPLICID     Application Identifier  Char
# 1       STUDYID           Study Identifier  Char
# 2        DOMAIN        Domain Abbreviation  Char
# 3       USUBJID  Unique Subject Identifier  Char
# 4         LBSEQ            Sequence Number   Num
#
#   Controlled\nTerms, Codelist or Format        Role  \
# 0                                   NaN  Identifier
# 1                                   NaN  Identifier
# 2                                    LB  Identifier
# 3                                   NaN  Identifier
# 4                                   NaN  Identifier
#
#                                          CDISC Notes Core         Remark
# 0                     Unique identifier for a study.  Req  User definded
# 1                     Unique identifier for a study.  Req            NaN
# 2         Two-character abbreviation for the domain.  Req            NaN
# 3  Identifier used to uniquely identify a subject...  Req            NaN
# 4  Sequence Number given to ensure uniqueness of ...  Req            NaN

# %%
# not collecting all the var at this moment - like ACTARM
df = df.iloc[:25,:]
df.tail(3)
# Out:
#    Variable Name                         Variable Label  Type  \
# 22         LBDTC      Date/Time of Specimen\nCollection  Char
# 23       LBENDTC  End Date/Time of\nSpecimen Collection  Char
# 24          LBDY      Study Day of Specimen\nCollection   Num
#
#    Controlled\nTerms, Codelist or Format    Role  \
# 22                              ISO 8601  Timing
# 23                              ISO 8601  Timing
# 24                                   NaN  Timing
#
#                                           CDISC Notes  Core Remark
# 22                                                NaN   Exp    NaN
# 23                                                NaN  Perm    NaN
# 24  1. Study day of specimen collection, measured ...  Perm    NaN

# %%
# Data elements needs to be extracted from LB domains
LB_data_elements = list(df['Variable Name'])

# %%
# Not all are present in Daclizumab LB domain. Hence, create an empty df with variables needed first

lb_df = pd.DataFrame(index = range(len(df_dac)), columns = LB_data_elements)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ece3f5afcf98> in <module>()
#       1 # Not all are present in Daclizumab LB domain. Hence, create an empty df with variables needed first
#       2
# ----> 3 lb_df = pd.DataFrame(index = range(len(df_dac)), columns = LB_data_elements)
#
# NameError: name 'df_dac' is not defined

# %%
# find common col var 
common_var = list(set(LB_data_elements).intersection(list(df_dac)))

# %%
len(common_var)
# Out:
# 20

# %%
# find the vars which are present in lb_df and missing in df_dac
list(set(LB_data_elements) - set(common_var))
# Out:
# [u'APPLICID', u'LBTOX', u'LBENDTC', u'LBFAST', u'LBSTNRC']

# %%
# find the vars which are missing in df_dac
list(set(list(df_dac)) - set(common_var))
# Out:
# [u'LBORRES',
#  u'LBORRESU',
#  u'LBORNRHI',
#  u'LBSCAT',
#  u'EPOCH',
#  u'LBREFID',
#  u'LBNAM',
#  u'LBORNRLO',
#  u'LBNRIND']

# %%
# fill up the dm_df with daclizumab data
lb_df['APPLICID'] = 'BLA761029'
lb_df[common_var] = df_dac[common_var]

# %%
# Check the LBTEST code values
dac_cd = set(list(lb_df['LBTESTCD']))

# %%
# Load the xls file's Sheet1 as a dataframe
df_code = data_elements_file.parse('LB CodeList')
df_code = df_code.iloc[:125,:]
df_code.tail(5)
# Out:
#      LBTESTCD                                   LBTEST LBTESTDSC  \
# 120  HCVGTYPE                             HCV Genotype       NaN
# 121    HCRTQE                      HCV RNA Taq 2.0-Exp       NaN
# 122    HEVRNA                    Hepatitis E Virus RNA       NaN
# 123     HIGMC     Herpes Sim.Virus 1/2 IgM IFA Confirm       NaN
# 124    HIGMIN  Herpes Sim.Virus 1/2 IgM Interpretation       NaN
#
#                  LBCAT LBSTRESU
# 120       MICROBIOLOGY      NaN
# 121         HEMATOLOGY      NaN
# 122         HEMATOLOGY      NaN
# 123  SPECIAL CHEMISTRY      NaN
# 124       MICROBIOLOGY      NaN

# %%
# code elements needs to be extracted from LB domains
req_code = list(df_code['LBTESTCD'])

# %%
# find common col var 
common_var = list(set(req_code).intersection(list(dac_cd)))

# %%
len(common_var)
# Out:
# 62

# %%
# find the code which are missing in dac_cd
unique_req_cd = list(set(req_code) - set(common_var))

# %%
df_dac[df_dac.LBTESTCD == "SCSPMS1P"].iloc[:,5:20]
# Out:
#          LBTESTCD                  LBTEST              LBCAT LBSCAT LBORRES  \
# 3366     SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 6774     SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 22212    SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 22899    SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 24485    SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 27393    SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 62443    SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 62444    SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY
# 63086    SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 78592    SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY
# 88140    SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 93971    SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 110585   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 132361   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY
# 138725   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 140081   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 144850   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 144851   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 144852   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 144853   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 146435   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 152441   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY
# 166200   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 169180   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 180436   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 186375   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 187141   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 197043   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 199955   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 212185   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# ...           ...                     ...                ...    ...     ...
# 832868   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 840981   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY
# 851636   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 882339   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 893234   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 896774   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 898942   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 930913   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 931512   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY
# 941268   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 948209   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 948210   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 950187   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 951675   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 957382   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 961732   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 961733   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 968675   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 968676   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY
# 968677   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 968678   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 968679   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 968680   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY
# 968681   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 976774   SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY
# 1004154  SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 1006067  SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 1012256  SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
# 1015737  SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY
# 1015738  SCSPMS1P  SPE-M-spike 1 -Percent  SPECIAL CHEMISTRY            0.0
#
#         LBORRESU LBORNRLO LBORNRHI LBSTRESC      LBSTRESN LBSTRESU  \
# 3366           %        0     9999        0  5.397605e-79        %
# 6774           %        0     9999        0  5.397605e-79        %
# 22212          %        0     9999        0  5.397605e-79        %
# 22899          %        0     9999        0  5.397605e-79        %
# 24485          %        0     9999        0  5.397605e-79        %
# 27393          %        0     9999        0  5.397605e-79        %
# 62443          %        0     9999        0  5.397605e-79        %
# 62444                   0     9999                    NaN
# 63086          %        0     9999        0  5.397605e-79        %
# 78592                   0     9999                    NaN
# 88140          %        0     9999        0  5.397605e-79        %
# 93971          %        0     9999        0  5.397605e-79        %
# 110585         %        0     9999        0  5.397605e-79        %
# 132361                  0     9999                    NaN
# 138725         %        0     9999        0  5.397605e-79        %
# 140081         %        0     9999        0  5.397605e-79        %
# 144850         %        0     9999        0  5.397605e-79        %
# 144851         %        0     9999        0  5.397605e-79        %
# 144852         %        0     9999        0  5.397605e-79        %
# 144853         %        0     9999        0  5.397605e-79        %
# 146435         %        0     9999        0  5.397605e-79        %
# 152441                  0     9999                    NaN
# 166200         %        0     9999        0  5.397605e-79        %
# 169180         %        0     9999        0  5.397605e-79        %
# 180436         %        0     9999        0  5.397605e-79        %
# 186375         %        0     9999        0  5.397605e-79        %
# 187141         %        0     9999        0  5.397605e-79        %
# 197043         %        0     9999        0  5.397605e-79        %
# 199955         %        0     9999        0  5.397605e-79        %
# 212185         %        0     9999        0  5.397605e-79        %
# ...          ...      ...      ...      ...           ...      ...
# 832868         %        0     9999        0  5.397605e-79        %
# 840981                  0     9999                    NaN
# 851636         %        0     9999        0  5.397605e-79        %
# 882339         %        0     9999        0  5.397605e-79        %
# 893234         %        0     9999        0  5.397605e-79        %
# 896774         %        0     9999        0  5.397605e-79        %
# 898942         %        0     9999        0  5.397605e-79        %
# 930913         %        0     9999        0  5.397605e-79        %
# 931512                  0     9999                    NaN
# 941268         %        0     9999        0  5.397605e-79        %
# 948209         %        0     9999        0  5.397605e-79        %
# 948210         %        0     9999        0  5.397605e-79        %
# 950187         %        0     9999        0  5.397605e-79        %
# 951675         %        0     9999        0  5.397605e-79        %
# 957382         %        0     9999        0  5.397605e-79        %
# 961732         %        0     9999        0  5.397605e-79        %
# 961733         %        0     9999        0  5.397605e-79        %
# 968675         %        0     9999        0  5.397605e-79        %
# 968676                  0     9999                    NaN
# 968677         %        0     9999        0  5.397605e-79        %
# 968678         %        0     9999        0  5.397605e-79        %
# 968679         %        0     9999        0  5.397605e-79        %
# 968680                  0     9999                    NaN
# 968681         %        0     9999        0  5.397605e-79        %
# 976774                  0     9999                    NaN
# 1004154        %        0     9999        0  5.397605e-79        %
# 1006067        %        0     9999        0  5.397605e-79        %
# 1012256        %        0     9999        0  5.397605e-79        %
# 1015737                 0     9999                    NaN
# 1015738        %        0     9999        0  5.397605e-79        %
#
#              LBSTNRLO  LBSTNRHI LBNRIND    LBSTAT
# 3366     5.397605e-79    9999.0       N
# 6774     5.397605e-79    9999.0       N
# 22212    5.397605e-79    9999.0       N
# 22899    5.397605e-79    9999.0       N
# 24485    5.397605e-79    9999.0       N
# 27393    5.397605e-79    9999.0       N
# 62443    5.397605e-79    9999.0       N
# 62444    5.397605e-79    9999.0          NOT DONE
# 63086    5.397605e-79    9999.0       N
# 78592    5.397605e-79    9999.0          NOT DONE
# 88140    5.397605e-79    9999.0       N
# 93971    5.397605e-79    9999.0       N
# 110585   5.397605e-79    9999.0       N
# 132361   5.397605e-79    9999.0          NOT DONE
# 138725   5.397605e-79    9999.0       N
# 140081   5.397605e-79    9999.0       N
# 144850   5.397605e-79    9999.0       N
# 144851   5.397605e-79    9999.0       N
# 144852   5.397605e-79    9999.0       N
# 144853   5.397605e-79    9999.0       N
# 146435   5.397605e-79    9999.0       N
# 152441   5.397605e-79    9999.0          NOT DONE
# 166200   5.397605e-79    9999.0       N
# 169180   5.397605e-79    9999.0       N
# 180436   5.397605e-79    9999.0       N
# 186375   5.397605e-79    9999.0       N
# 187141   5.397605e-79    9999.0       N
# 197043   5.397605e-79    9999.0       N
# 199955   5.397605e-79    9999.0       N
# 212185   5.397605e-79    9999.0       N
# ...               ...       ...     ...       ...
# 832868   5.397605e-79    9999.0       N
# 840981   5.397605e-79    9999.0          NOT DONE
# 851636   5.397605e-79    9999.0       N
# 882339   5.397605e-79    9999.0       N
# 893234   5.397605e-79    9999.0       N
# 896774   5.397605e-79    9999.0       N
# 898942   5.397605e-79    9999.0       N
# 930913   5.397605e-79    9999.0       N
# 931512   5.397605e-79    9999.0          NOT DONE
# 941268   5.397605e-79    9999.0       N
# 948209   5.397605e-79    9999.0       N
# 948210   5.397605e-79    9999.0       N
# 950187   5.397605e-79    9999.0       N
# 951675   5.397605e-79    9999.0       N
# 957382   5.397605e-79    9999.0       N
# 961732   5.397605e-79    9999.0       N
# 961733   5.397605e-79    9999.0       N
# 968675   5.397605e-79    9999.0       N
# 968676   5.397605e-79    9999.0          NOT DONE
# 968677   5.397605e-79    9999.0       N
# 968678   5.397605e-79    9999.0       N
# 968679   5.397605e-79    9999.0       N
# 968680   5.397605e-79    9999.0          NOT DONE
# 968681   5.397605e-79    9999.0       N
# 976774   5.397605e-79    9999.0          NOT DONE
# 1004154  5.397605e-79    9999.0       N
# 1006067  5.397605e-79    9999.0       N
# 1012256  5.397605e-79    9999.0       N
# 1015737  5.397605e-79    9999.0          NOT DONE
# 1015738  5.397605e-79    9999.0       N
#
# [123 rows x 15 columns]

# %%
# find the code which are unique to dac_code
unique_dac_cd = list(set(dac_cd) - set(common_var))

# %%
unique_dac_cd
# Out:
# ['KETONES',
#  'NEUTLE',
#  'SCSPMSR1',
#  'BACT',
#  'SCSPMSR2',
#  'FATBODOV',
#  'CYTRPHOS',
#  'CYCAOXA',
#  'SODIUM',
#  'GLOBG',
#  'MONO',
#  'GLOBBPT',
#  'GLOBB',
#  'PHENTHZ',
#  'CYCACAR',
#  'HS12GMAI',
#  'CSWAX',
#  'GLOBA2PT',
#  'EPITUCE',
#  'HEVVLD',
#  'GLOBA1PT',
#  'RBCCLMP',
#  'GTTYIELD',
#  'NEUTBLE',
#  'GTYIELD1',
#  'GTYIELD2',
#  'EPITCE',
#  'NEUTB',
#  'CYCAPHOS',
#  'SLAGAB',
#  'EPISQCE',
#  'PB19VLD',
#  'METHQLDN',
#  'EBCIGMAG',
#  'LYMATLE',
#  'METAMYLE',
#  'NEUTSGLE',
#  'GTA260_1',
#  'COLOR',
#  'CYCYSTIN',
#  'BUN',
#  'MYCY',
#  'WBCCLMP',
#  'PH',
#  'EOSLE',
#  'K',
#  'SCSPMS2P',
#  'HCG',
#  'GLOBGPT',
#  'LYMLE',
#  'GTCONCN1',
#  'GTCONCN2',
#  'MCHC',
#  'SCVZIGMT',
#  'METAMY',
#  'GTPURITY',
#  'MUCTHR',
#  'RBCMORPH',
#  'NEUT',
#  'EBN1IGAB',
#  'MONOLE',
#  'YEASTBUD',
#  'CSHYAL',
#  'CYTYRO',
#  'CYURIAC',
#  'HAABIGM',
#  'APAP',
#  'LEUKASE',
#  'VZVINTP',
#  'CYAMORPH',
#  'CSGRAN',
#  'CYAMMBIU',
#  'MYCYLE',
#  'BASOLE',
#  'ALBPROT',
#  'SCSPMSQ1',
#  'SCSPMSQ2',
#  'GTVOL2',
#  'YEASTHYP',
#  'GTVOL1',
#  'APPEAR',
#  'CYBILI',
#  'SPGRAV',
#  'SPERM',
#  'GTHVOL',
#  'GLOBA2',
#  'GLOBA1',
#  'ANTIDPRS',
#  'HHV6VLD',
#  'CYLEUC',
#  'FERRITIN',
#  'SCSPMS1P',
#  'HERNA',
#  'FAT',
#  'NITRITE',
#  'SCVZVTET',
#  'GTSVOL',
#  'TRICH',
#  'WBCCOVAL',
#  'SEDEXAM',
#  'OCCBLD',
#  'GTA280_1',
#  'RBC',
#  'LYMAT',
#  'MCH',
#  'GTCONCEN',
#  'MCV']

# %%
# Drop duplicate rows from df_dac
df_dac_unique = df_dac.drop_duplicates(['LBTESTCD'], keep = 'first')

# %%
# req_code df with unique req code 
unique_df_code = df_code[df_code.LBTESTCD.isin(unique_req_cd)]

# %%
#dac_df with unique dac_code 
df_dac_unique = df_dac_unique[df_dac_unique.LBTESTCD.isin(unique_dac_cd)]

# %%
# dac_df dictionary with unique LBTEST and LBTESTCD
unique_dac_lbtest = dict(zip(df_dac_unique.LBTESTCD,df_dac_unique.LBTEST))

# %%
# req_code_df dictionary with unique LBTEST and LBTESTCD
unique_req_lbtest = dict(zip(unique_df_code.LBTESTCD,unique_df_code.LBTEST))

# %%
ndf = pd.DataFrame(columns = ['LBTESTCD-80','LBTEST-80','a_LBTESTCD-80','a_LBTEST-80'])

# %%
i = 0
for k,v in unique_req_lbtest.items():
    for k1,v1 in unique_dac_lbtest.items():
        
        if difflib.SequenceMatcher(None,v,v1).ratio() >=0.8 :
            ndf.loc[i] =[k,v,k1,v1]
            print ndf.loc[i]
            i += 1
           
            #print v,'\t\t',v1,'\t\t',k,'\t\t',k1
# Out:
# LBTESTCD-80                                HBAB
# LBTEST-80            Hepatitis B Virus Antibody
# a_LBTESTCD-80                           HAABIGM
# a_LBTEST-80      Hepatitis A Virus Antibody IgM
# Name: 0, dtype: object
# LBTESTCD-80                              EBCIGMAB
# LBTEST-80        Epstein-Barr Capsid IgM Antibody
# a_LBTESTCD-80                            EBCIGMAG
# a_LBTEST-80       Epstein-Barr Capsid IgM Antigen
# Name: 1, dtype: object
# LBTESTCD-80                                HEAB
# LBTEST-80            Hepatitis E Virus Antibody
# a_LBTESTCD-80                           HAABIGM
# a_LBTEST-80      Hepatitis A Virus Antibody IgM
# Name: 2, dtype: object
# LBTESTCD-80                    UREAN
# LBTEST-80              Urea Nitrogen
# a_LBTESTCD-80                    BUN
# a_LBTEST-80      Blood Urea Nitrogen
# Name: 3, dtype: object
# LBTESTCD-80                               HBEAB
# LBTEST-80          Hepatitis B Virus e Antibody
# a_LBTESTCD-80                           HAABIGM
# a_LBTEST-80      Hepatitis A Virus Antibody IgM
# Name: 4, dtype: object
# LBTESTCD-80                HAVVLD
# LBTEST-80          HAV Viral Load
# a_LBTESTCD-80             HHV6VLD
# a_LBTEST-80      HHV-6 Viral Load
# Name: 5, dtype: object
# LBTESTCD-80                                HCAG
# LBTEST-80             Hepatitis C Virus Antigen
# a_LBTESTCD-80                           HAABIGM
# a_LBTEST-80      Hepatitis A Virus Antibody IgM
# Name: 6, dtype: object
# LBTESTCD-80                HIVVLD
# LBTEST-80          HIV Viral Load
# a_LBTESTCD-80             HHV6VLD
# a_LBTEST-80      HHV-6 Viral Load
# Name: 7, dtype: object
# LBTESTCD-80                                HDAB
# LBTEST-80            Hepatitis D Virus Antibody
# a_LBTESTCD-80                           HAABIGM
# a_LBTEST-80      Hepatitis A Virus Antibody IgM
# Name: 8, dtype: object
# LBTESTCD-80                EBVVLD
# LBTEST-80          EBV Viral Load
# a_LBTESTCD-80             HHV6VLD
# a_LBTEST-80      HHV-6 Viral Load
# Name: 9, dtype: object
# LBTESTCD-80                             HAIGMAB
# LBTEST-80        Hepatitis A Virus IgM Antibody
# a_LBTESTCD-80                           HAABIGM
# a_LBTEST-80      Hepatitis A Virus Antibody IgM
# Name: 10, dtype: object
# LBTESTCD-80                CMVVLD
# LBTEST-80          CMV Viral Load
# a_LBTESTCD-80             HHV6VLD
# a_LBTEST-80      HHV-6 Viral Load
# Name: 11, dtype: object
# LBTESTCD-80              ACTMN
# LBTEST-80        Acetaminophen
# a_LBTESTCD-80             APAP
# a_LBTEST-80      Acetaminophen
# Name: 12, dtype: object
# LBTESTCD-80                             HDIGMAB
# LBTEST-80        Hepatitis D Virus IgM Antibody
# a_LBTESTCD-80                           HAABIGM
# a_LBTEST-80      Hepatitis A Virus Antibody IgM
# Name: 13, dtype: object
# LBTESTCD-80                                SLAIGGAB
# LBTEST-80        Soluble Liver Antigen IgG Antibody
# a_LBTESTCD-80                                SLAGAB
# a_LBTEST-80          Soluble Liver Antigen Antibody
# Name: 14, dtype: object
# LBTESTCD-80                     HEVRNA
# LBTEST-80        Hepatitis E Virus RNA
# a_LBTESTCD-80                    HERNA
# a_LBTEST-80            Hepatitis E RNA
# Name: 15, dtype: object
# LBTESTCD-80                HDVVLD
# LBTEST-80          HDV Viral Load
# a_LBTESTCD-80             HHV6VLD
# a_LBTEST-80      HHV-6 Viral Load
# Name: 16, dtype: object
# LBTESTCD-80                             HDIGGAB
# LBTEST-80        Hepatitis D Virus IgG Antibody
# a_LBTESTCD-80                           HAABIGM
# a_LBTEST-80      Hepatitis A Virus Antibody IgM
# Name: 17, dtype: object
# LBTESTCD-80                              EBCIGGAB
# LBTEST-80        Epstein-Barr Capsid IgG Antibody
# a_LBTESTCD-80                            EBCIGMAG
# a_LBTEST-80       Epstein-Barr Capsid IgM Antigen
# Name: 18, dtype: object

# %%
 ndf
# Out:
#    LBTESTCD-80                           LBTEST-80 a_LBTESTCD-80  \
# 0         HBAB          Hepatitis B Virus Antibody       HAABIGM
# 1     EBCIGMAB    Epstein-Barr Capsid IgM Antibody      EBCIGMAG
# 2         HEAB          Hepatitis E Virus Antibody       HAABIGM
# 3        UREAN                       Urea Nitrogen           BUN
# 4        HBEAB        Hepatitis B Virus e Antibody       HAABIGM
# 5       HAVVLD                      HAV Viral Load       HHV6VLD
# 6         HCAG           Hepatitis C Virus Antigen       HAABIGM
# 7       HIVVLD                      HIV Viral Load       HHV6VLD
# 8         HDAB          Hepatitis D Virus Antibody       HAABIGM
# 9       EBVVLD                      EBV Viral Load       HHV6VLD
# 10     HAIGMAB      Hepatitis A Virus IgM Antibody       HAABIGM
# 11      CMVVLD                      CMV Viral Load       HHV6VLD
# 12       ACTMN                       Acetaminophen          APAP
# 13     HDIGMAB      Hepatitis D Virus IgM Antibody       HAABIGM
# 14    SLAIGGAB  Soluble Liver Antigen IgG Antibody        SLAGAB
# 15      HEVRNA               Hepatitis E Virus RNA         HERNA
# 16      HDVVLD                      HDV Viral Load       HHV6VLD
# 17     HDIGGAB      Hepatitis D Virus IgG Antibody       HAABIGM
# 18    EBCIGGAB    Epstein-Barr Capsid IgG Antibody      EBCIGMAG
#
#                         a_LBTEST-80
# 0    Hepatitis A Virus Antibody IgM
# 1   Epstein-Barr Capsid IgM Antigen
# 2    Hepatitis A Virus Antibody IgM
# 3               Blood Urea Nitrogen
# 4    Hepatitis A Virus Antibody IgM
# 5                  HHV-6 Viral Load
# 6    Hepatitis A Virus Antibody IgM
# 7                  HHV-6 Viral Load
# 8    Hepatitis A Virus Antibody IgM
# 9                  HHV-6 Viral Load
# 10   Hepatitis A Virus Antibody IgM
# 11                 HHV-6 Viral Load
# 12                    Acetaminophen
# 13   Hepatitis A Virus Antibody IgM
# 14   Soluble Liver Antigen Antibody
# 15                  Hepatitis E RNA
# 16                 HHV-6 Viral Load
# 17   Hepatitis A Virus Antibody IgM
# 18  Epstein-Barr Capsid IgM Antigen

# %%
ndf2 = pd.DataFrame(columns = ['LBTESTCD80-50','LBTEST80-50','a_LBTESTCD80-50','a_LBTEST80-50'])
i = 0
for k,v in unique_req_lbtest.items():
    for k1,v1 in unique_dac_lbtest.items():
        
        if 0.8 > difflib.SequenceMatcher(None,v,v1).ratio() >= 0.5 :
            ndf2.loc[i] =[k,v,k1,v1]
            i += 1
           
            #print v,'\t\t',v1,'\t\t',k,'\t\t',k1

# %%
ndf2
# Out:
#    LBTESTCD80-50                              LBTEST80-50 a_LBTESTCD80-50  \
# 0         HBVVLD                   HBV Viral Load (IU/mL)          HEVVLD
# 1         HBVVLD                   HBV Viral Load (IU/mL)         PB19VLD
# 2         HBVVLD                   HBV Viral Load (IU/mL)         HHV6VLD
# 3           HBAB               Hepatitis B Virus Antibody          HEVVLD
# 4           HBAB               Hepatitis B Virus Antibody           HERNA
# 5       LYMPHOTC                             Lymphotactin           LYMLE
# 6       LYMPHOTC                             Lymphotactin           LYMAT
# 7          HIVAB                             HIV Antibody         HAABIGM
# 8       EBCIGMAB         Epstein-Barr Capsid IgM Antibody        EBN1IGAB
# 9       SMUSCGAB               Smooth Muscle IgG Antibody          SLAGAB
# 10        IFNB\n                          Interferon Beta             HCG
# 11       HIV12AB                         HIV-1/2 Antibody        HS12GMAI
# 12         VZVAB          Varicella Zoster Virus Antibody         HAABIGM
# 13          HEAB               Hepatitis E Virus Antibody          HEVVLD
# 14          HEAB               Hepatitis E Virus Antibody           HERNA
# 15      VZVIGAAB      Varicella Zoster Virus IgA Antibody         HAABIGM
# 16         UREAN                            Urea Nitrogen         NITRITE
# 17         HBEAG              Hepatitis B Virus e Antigen          HEVVLD
# 18         HBEAG              Hepatitis B Virus e Antigen         HAABIGM
# 19         HBEAG              Hepatitis B Virus e Antigen           HERNA
# 20      NEUTSGNE        Segmented Neutrophils/Neutrophils          NEUTLE
# 21      NEUTSGNE        Segmented Neutrophils/Neutrophils            NEUT
# 22         HBEAB             Hepatitis B Virus e Antibody          HEVVLD
# 23         HBEAB             Hepatitis B Virus e Antibody           HERNA
# 24      HBCIGGAB      Hepatitis B Virus Core IgG Antibody          HEVVLD
# 25      HBCIGGAB      Hepatitis B Virus Core IgG Antibody         HAABIGM
# 26        HAVVLD                           HAV Viral Load          HEVVLD
# 27        HAVVLD                           HAV Viral Load         PB19VLD
# 28          HCAG                Hepatitis C Virus Antigen          HEVVLD
# 29          HCAG                Hepatitis C Virus Antigen           HERNA
# ..           ...                                      ...             ...
# 57        HIGMIN  Herpes Sim.Virus 1/2 IgM Interpretation        HS12GMAI
# 58         HS6AB          Herpes Simplex Virus 6 Antibody         HAABIGM
# 59       HDIGMAB           Hepatitis D Virus IgM Antibody          HEVVLD
# 60       HDIGMAB           Hepatitis D Virus IgM Antibody           HERNA
# 61      SLAIGGAB       Soluble Liver Antigen IgG Antibody        EBN1IGAB
# 62          LYMA                   Lymphocytes Activated          LYMATLE
# 63          LYMA                   Lymphocytes Activated            LYMLE
# 64          LYMA                   Lymphocytes Activated            LYMAT
# 65         EOSCE                  Eosinophils/Total Cells         EPITUCE
# 66         EOSCE                  Eosinophils/Total Cells          EPITCE
# 67         EOSCE                  Eosinophils/Total Cells         EPISQCE
# 68         EOSCE                  Eosinophils/Total Cells           EOSLE
# 69         EOSCE                  Eosinophils/Total Cells          BASOLE
# 70        HEVRNA                    Hepatitis E Virus RNA          HEVVLD
# 71        HEVRNA                    Hepatitis E Virus RNA         HAABIGM
# 72      HS1IGMAB      Herpes Simplex Virus 1 IgM Antibody        HS12GMAI
# 73      HS1IGMAB      Herpes Simplex Virus 1 IgM Antibody         HAABIGM
# 74        HDVVLD                           HDV Viral Load          HEVVLD
# 75        HDVVLD                           HDV Viral Load         PB19VLD
# 76       HDIGGAB           Hepatitis D Virus IgG Antibody          HEVVLD
# 77       HDIGGAB           Hepatitis D Virus IgG Antibody           HERNA
# 78      EBCIGGAB         Epstein-Barr Capsid IgG Antibody        EBN1IGAB
# 79        BASOCE                    Basophils/Total Cells          NEUTLE
# 80        BASOCE                    Basophils/Total Cells         GLOBBPT
# 81        BASOCE                    Basophils/Total Cells         EPITUCE
# 82        BASOCE                    Basophils/Total Cells        GTTYIELD
# 83        BASOCE                    Basophils/Total Cells          EPITCE
# 84        BASOCE                    Basophils/Total Cells         EPISQCE
# 85        BASOCE                    Basophils/Total Cells           EOSLE
# 86        BASOCE                    Basophils/Total Cells          BASOLE
#
#                             a_LBTEST80-50
# 0                  Hepatitis E Viral Load
# 1               Parvovirus B19 Viral Load
# 2                        HHV-6 Viral Load
# 3                  Hepatitis E Viral Load
# 4                         Hepatitis E RNA
# 5                  Lymphocytes/Leukocytes
# 6                    Lymphocytes Atypical
# 7          Hepatitis A Virus Antibody IgM
# 8   Epstein-Barr Nuclear Antigen 1 IgG Ab
# 9          Soluble Liver Antigen Antibody
# 10                Choriogonadotropin Beta
# 11    HSV 1/2 IgM Antibody Interpretation
# 12         Hepatitis A Virus Antibody IgM
# 13                 Hepatitis E Viral Load
# 14                        Hepatitis E RNA
# 15         Hepatitis A Virus Antibody IgM
# 16                                Nitrite
# 17                 Hepatitis E Viral Load
# 18         Hepatitis A Virus Antibody IgM
# 19                        Hepatitis E RNA
# 20                 Neutrophils/Leukocytes
# 21                            Neutrophils
# 22                 Hepatitis E Viral Load
# 23                        Hepatitis E RNA
# 24                 Hepatitis E Viral Load
# 25         Hepatitis A Virus Antibody IgM
# 26                 Hepatitis E Viral Load
# 27              Parvovirus B19 Viral Load
# 28                 Hepatitis E Viral Load
# 29                        Hepatitis E RNA
# ..                                    ...
# 57    HSV 1/2 IgM Antibody Interpretation
# 58         Hepatitis A Virus Antibody IgM
# 59                 Hepatitis E Viral Load
# 60                        Hepatitis E RNA
# 61  Epstein-Barr Nuclear Antigen 1 IgG Ab
# 62        Lymphocytes Atypical/Leukocytes
# 63                 Lymphocytes/Leukocytes
# 64                   Lymphocytes Atypical
# 65               Tubular Epithelial Cells
# 66          Transitional Epithelial Cells
# 67              Squamous Epithelial Cells
# 68                 Eosinophils/Leukocytes
# 69                   Basophils/Leukocytes
# 70                 Hepatitis E Viral Load
# 71         Hepatitis A Virus Antibody IgM
# 72    HSV 1/2 IgM Antibody Interpretation
# 73         Hepatitis A Virus Antibody IgM
# 74                 Hepatitis E Viral Load
# 75              Parvovirus B19 Viral Load
# 76                 Hepatitis E Viral Load
# 77                        Hepatitis E RNA
# 78  Epstein-Barr Nuclear Antigen 1 IgG Ab
# 79                 Neutrophils/Leukocytes
# 80            Beta Globulin/Total Protein
# 81               Tubular Epithelial Cells
# 82                            Total Yield
# 83          Transitional Epithelial Cells
# 84              Squamous Epithelial Cells
# 85                 Eosinophils/Leukocytes
# 86                   Basophils/Leukocytes
#
# [87 rows x 4 columns]

# %%
ndf3 = pd.DataFrame(columns = ['LBTESTCD - below50','LBTEST- below50','a_LBTESTCD- below50','a_LBTEST- below50'])
i = 0
for k,v in unique_req_lbtest.items():
    for k1,v1 in unique_dac_lbtest.items():
        
        if difflib.SequenceMatcher(None,v,v1).ratio() < 0.5 :
            ndf3.loc[i] =[k,v,k1,v1]
            i += 1
           
            #print v,'\t\t',v1,'\t\t',k,'\t\t',k1

# %%
ndf3
# Out:
#      LBTESTCD - below50         LBTEST- below50 a_LBTESTCD- below50  \
# 0                HBVVLD  HBV Viral Load (IU/mL)             KETONES
# 1                HBVVLD  HBV Viral Load (IU/mL)              NEUTLE
# 2                HBVVLD  HBV Viral Load (IU/mL)            SCSPMSR1
# 3                HBVVLD  HBV Viral Load (IU/mL)                BACT
# 4                HBVVLD  HBV Viral Load (IU/mL)            SCSPMSR2
# 5                HBVVLD  HBV Viral Load (IU/mL)            FATBODOV
# 6                HBVVLD  HBV Viral Load (IU/mL)            CYTRPHOS
# 7                HBVVLD  HBV Viral Load (IU/mL)             CYCAOXA
# 8                HBVVLD  HBV Viral Load (IU/mL)              SODIUM
# 9                HBVVLD  HBV Viral Load (IU/mL)               GLOBG
# 10               HBVVLD  HBV Viral Load (IU/mL)                MONO
# 11               HBVVLD  HBV Viral Load (IU/mL)             GLOBBPT
# 12               HBVVLD  HBV Viral Load (IU/mL)               GLOBB
# 13               HBVVLD  HBV Viral Load (IU/mL)             PHENTHZ
# 14               HBVVLD  HBV Viral Load (IU/mL)             CYCACAR
# 15               HBVVLD  HBV Viral Load (IU/mL)            HS12GMAI
# 16               HBVVLD  HBV Viral Load (IU/mL)               CSWAX
# 17               HBVVLD  HBV Viral Load (IU/mL)            GLOBA2PT
# 18               HBVVLD  HBV Viral Load (IU/mL)             EPITUCE
# 19               HBVVLD  HBV Viral Load (IU/mL)            GLOBA1PT
# 20               HBVVLD  HBV Viral Load (IU/mL)             RBCCLMP
# 21               HBVVLD  HBV Viral Load (IU/mL)            GTTYIELD
# 22               HBVVLD  HBV Viral Load (IU/mL)             NEUTBLE
# 23               HBVVLD  HBV Viral Load (IU/mL)            GTYIELD1
# 24               HBVVLD  HBV Viral Load (IU/mL)            GTYIELD2
# 25               HBVVLD  HBV Viral Load (IU/mL)              EPITCE
# 26               HBVVLD  HBV Viral Load (IU/mL)               NEUTB
# 27               HBVVLD  HBV Viral Load (IU/mL)            CYCAPHOS
# 28               HBVVLD  HBV Viral Load (IU/mL)              SLAGAB
# 29               HBVVLD  HBV Viral Load (IU/mL)             EPISQCE
# ...                 ...                     ...                 ...
# 6498             BASOCE   Basophils/Total Cells            SCSPMSQ2
# 6499             BASOCE   Basophils/Total Cells              GTVOL2
# 6500             BASOCE   Basophils/Total Cells            YEASTHYP
# 6501             BASOCE   Basophils/Total Cells              GTVOL1
# 6502             BASOCE   Basophils/Total Cells              APPEAR
# 6503             BASOCE   Basophils/Total Cells              CYBILI
# 6504             BASOCE   Basophils/Total Cells               SPERM
# 6505             BASOCE   Basophils/Total Cells              GTHVOL
# 6506             BASOCE   Basophils/Total Cells              GLOBA2
# 6507             BASOCE   Basophils/Total Cells              GLOBA1
# 6508             BASOCE   Basophils/Total Cells            ANTIDPRS
# 6509             BASOCE   Basophils/Total Cells             HHV6VLD
# 6510             BASOCE   Basophils/Total Cells              CYLEUC
# 6511             BASOCE   Basophils/Total Cells            FERRITIN
# 6512             BASOCE   Basophils/Total Cells            SCSPMS1P
# 6513             BASOCE   Basophils/Total Cells               HERNA
# 6514             BASOCE   Basophils/Total Cells                 FAT
# 6515             BASOCE   Basophils/Total Cells             NITRITE
# 6516             BASOCE   Basophils/Total Cells            SCVZVTET
# 6517             BASOCE   Basophils/Total Cells              GTSVOL
# 6518             BASOCE   Basophils/Total Cells               TRICH
# 6519             BASOCE   Basophils/Total Cells            WBCCOVAL
# 6520             BASOCE   Basophils/Total Cells             SEDEXAM
# 6521             BASOCE   Basophils/Total Cells              OCCBLD
# 6522             BASOCE   Basophils/Total Cells            GTA280_1
# 6523             BASOCE   Basophils/Total Cells                 RBC
# 6524             BASOCE   Basophils/Total Cells               LYMAT
# 6525             BASOCE   Basophils/Total Cells                 MCH
# 6526             BASOCE   Basophils/Total Cells            GTCONCEN
# 6527             BASOCE   Basophils/Total Cells                 MCV
#
#                         a_LBTEST- below50
# 0                                 Ketones
# 1                  Neutrophils/Leukocytes
# 2                       SPE M-spike Reg.1
# 3                                Bacteria
# 4                       SPE M-spike Reg.2
# 5                        Fat Bodies, Oval
# 6               Triple Phosphate Crystals
# 7                Calcium Oxalate Crystals
# 8                                  Sodium
# 9                          Gamma Globulin
# 10                              Monocytes
# 11            Beta Globulin/Total Protein
# 12                          Beta Globulin
# 13                          Phenothiazine
# 14             Calcium Carbonate Crystals
# 15    HSV 1/2 IgM Antibody Interpretation
# 16                             Waxy Casts
# 17         Alpha-2 Globulin/Total Protein
# 18               Tubular Epithelial Cells
# 19         Alpha-1 Globulin/Total Protein
# 20                Erythrocyte Cell Clumps
# 21                            Total Yield
# 22       Neutrophils Band Form/Leukocytes
# 23                        Aliquot 1 Yield
# 24                        Aliquot 2 Yield
# 25          Transitional Epithelial Cells
# 26                  Neutrophils Band Form
# 27             Calcium Phosphate Crystals
# 28         Soluble Liver Antigen Antibody
# 29              Squamous Epithelial Cells
# ...                                   ...
# 6498                    SPE M-spike Qty 2
# 6499             Aliquot Volume in Tube 2
# 6500                         Yeast Hyphae
# 6501             Aliquot Volume in Tube 1
# 6502                  Specimen Appearance
# 6503                   Bilirubin Crystals
# 6504                          Spermatozoa
# 6505                     Hydration Volume
# 6506                     Alpha-2 Globulin
# 6507                     Alpha-1 Globulin
# 6508                      Antidepressants
# 6509                     HHV-6 Viral Load
# 6510                     Leucine Crystals
# 6511                             Ferritin
# 6512               SPE-M-spike 1 -Percent
# 6513                      Hepatitis E RNA
# 6514                                  Fat
# 6515                              Nitrite
# 6516            VZV Tot(ACIF) Endpt Titer
# 6517                        Sample Volume
# 6518                          Trichomonas
# 6519                         WBC Comments
# 6520                 Sediment Examination
# 6521                         Occult Blood
# 6522                                 A280
# 6523                         Erythrocytes
# 6524                 Lymphocytes Atypical
# 6525     Ery. Mean Corpuscular Hemoglobin
# 6526                        Concentration
# 6527         Ery. Mean Corpuscular Volume
#
# [6528 rows x 4 columns]

# %%
result = pd.concat([ndf,ndf2,ndf3], axis=1)

# %%
result
# Out:
#      LBTESTCD-80                           LBTEST-80 a_LBTESTCD-80  \
# 0           HBAB          Hepatitis B Virus Antibody       HAABIGM
# 1       EBCIGMAB    Epstein-Barr Capsid IgM Antibody      EBCIGMAG
# 2           HEAB          Hepatitis E Virus Antibody       HAABIGM
# 3          UREAN                       Urea Nitrogen           BUN
# 4          HBEAB        Hepatitis B Virus e Antibody       HAABIGM
# 5         HAVVLD                      HAV Viral Load       HHV6VLD
# 6           HCAG           Hepatitis C Virus Antigen       HAABIGM
# 7         HIVVLD                      HIV Viral Load       HHV6VLD
# 8           HDAB          Hepatitis D Virus Antibody       HAABIGM
# 9         EBVVLD                      EBV Viral Load       HHV6VLD
# 10       HAIGMAB      Hepatitis A Virus IgM Antibody       HAABIGM
# 11        CMVVLD                      CMV Viral Load       HHV6VLD
# 12         ACTMN                       Acetaminophen          APAP
# 13       HDIGMAB      Hepatitis D Virus IgM Antibody       HAABIGM
# 14      SLAIGGAB  Soluble Liver Antigen IgG Antibody        SLAGAB
# 15        HEVRNA               Hepatitis E Virus RNA         HERNA
# 16        HDVVLD                      HDV Viral Load       HHV6VLD
# 17       HDIGGAB      Hepatitis D Virus IgG Antibody       HAABIGM
# 18      EBCIGGAB    Epstein-Barr Capsid IgG Antibody      EBCIGMAG
# 19           NaN                                 NaN           NaN
# 20           NaN                                 NaN           NaN
# 21           NaN                                 NaN           NaN
# 22           NaN                                 NaN           NaN
# 23           NaN                                 NaN           NaN
# 24           NaN                                 NaN           NaN
# 25           NaN                                 NaN           NaN
# 26           NaN                                 NaN           NaN
# 27           NaN                                 NaN           NaN
# 28           NaN                                 NaN           NaN
# 29           NaN                                 NaN           NaN
# ...          ...                                 ...           ...
# 6498         NaN                                 NaN           NaN
# 6499         NaN                                 NaN           NaN
# 6500         NaN                                 NaN           NaN
# 6501         NaN                                 NaN           NaN
# 6502         NaN                                 NaN           NaN
# 6503         NaN                                 NaN           NaN
# 6504         NaN                                 NaN           NaN
# 6505         NaN                                 NaN           NaN
# 6506         NaN                                 NaN           NaN
# 6507         NaN                                 NaN           NaN
# 6508         NaN                                 NaN           NaN
# 6509         NaN                                 NaN           NaN
# 6510         NaN                                 NaN           NaN
# 6511         NaN                                 NaN           NaN
# 6512         NaN                                 NaN           NaN
# 6513         NaN                                 NaN           NaN
# 6514         NaN                                 NaN           NaN
# 6515         NaN                                 NaN           NaN
# 6516         NaN                                 NaN           NaN
# 6517         NaN                                 NaN           NaN
# 6518         NaN                                 NaN           NaN
# 6519         NaN                                 NaN           NaN
# 6520         NaN                                 NaN           NaN
# 6521         NaN                                 NaN           NaN
# 6522         NaN                                 NaN           NaN
# 6523         NaN                                 NaN           NaN
# 6524         NaN                                 NaN           NaN
# 6525         NaN                                 NaN           NaN
# 6526         NaN                                 NaN           NaN
# 6527         NaN                                 NaN           NaN
#
#                           a_LBTEST-80 LBTESTCD80-50  \
# 0      Hepatitis A Virus Antibody IgM        HBVVLD
# 1     Epstein-Barr Capsid IgM Antigen        HBVVLD
# 2      Hepatitis A Virus Antibody IgM        HBVVLD
# 3                 Blood Urea Nitrogen          HBAB
# 4      Hepatitis A Virus Antibody IgM          HBAB
# 5                    HHV-6 Viral Load      LYMPHOTC
# 6      Hepatitis A Virus Antibody IgM      LYMPHOTC
# 7                    HHV-6 Viral Load         HIVAB
# 8      Hepatitis A Virus Antibody IgM      EBCIGMAB
# 9                    HHV-6 Viral Load      SMUSCGAB
# 10     Hepatitis A Virus Antibody IgM        IFNB\n
# 11                   HHV-6 Viral Load       HIV12AB
# 12                      Acetaminophen         VZVAB
# 13     Hepatitis A Virus Antibody IgM          HEAB
# 14     Soluble Liver Antigen Antibody          HEAB
# 15                    Hepatitis E RNA      VZVIGAAB
# 16                   HHV-6 Viral Load         UREAN
# 17     Hepatitis A Virus Antibody IgM         HBEAG
# 18    Epstein-Barr Capsid IgM Antigen         HBEAG
# 19                                NaN         HBEAG
# 20                                NaN      NEUTSGNE
# 21                                NaN      NEUTSGNE
# 22                                NaN         HBEAB
# 23                                NaN         HBEAB
# 24                                NaN      HBCIGGAB
# 25                                NaN      HBCIGGAB
# 26                                NaN        HAVVLD
# 27                                NaN        HAVVLD
# 28                                NaN          HCAG
# 29                                NaN          HCAG
# ...                               ...           ...
# 6498                              NaN           NaN
# 6499                              NaN           NaN
# 6500                              NaN           NaN
# 6501                              NaN           NaN
# 6502                              NaN           NaN
# 6503                              NaN           NaN
# 6504                              NaN           NaN
# 6505                              NaN           NaN
# 6506                              NaN           NaN
# 6507                              NaN           NaN
# 6508                              NaN           NaN
# 6509                              NaN           NaN
# 6510                              NaN           NaN
# 6511                              NaN           NaN
# 6512                              NaN           NaN
# 6513                              NaN           NaN
# 6514                              NaN           NaN
# 6515                              NaN           NaN
# 6516                              NaN           NaN
# 6517                              NaN           NaN
# 6518                              NaN           NaN
# 6519                              NaN           NaN
# 6520                              NaN           NaN
# 6521                              NaN           NaN
# 6522                              NaN           NaN
# 6523                              NaN           NaN
# 6524                              NaN           NaN
# 6525                              NaN           NaN
# 6526                              NaN           NaN
# 6527                              NaN           NaN
#
#                               LBTEST80-50 a_LBTESTCD80-50  \
# 0                  HBV Viral Load (IU/mL)          HEVVLD
# 1                  HBV Viral Load (IU/mL)         PB19VLD
# 2                  HBV Viral Load (IU/mL)         HHV6VLD
# 3              Hepatitis B Virus Antibody          HEVVLD
# 4              Hepatitis B Virus Antibody           HERNA
# 5                            Lymphotactin           LYMLE
# 6                            Lymphotactin           LYMAT
# 7                            HIV Antibody         HAABIGM
# 8        Epstein-Barr Capsid IgM Antibody        EBN1IGAB
# 9              Smooth Muscle IgG Antibody          SLAGAB
# 10                        Interferon Beta             HCG
# 11                       HIV-1/2 Antibody        HS12GMAI
# 12        Varicella Zoster Virus Antibody         HAABIGM
# 13             Hepatitis E Virus Antibody          HEVVLD
# 14             Hepatitis E Virus Antibody           HERNA
# 15    Varicella Zoster Virus IgA Antibody         HAABIGM
# 16                          Urea Nitrogen         NITRITE
# 17            Hepatitis B Virus e Antigen          HEVVLD
# 18            Hepatitis B Virus e Antigen         HAABIGM
# 19            Hepatitis B Virus e Antigen           HERNA
# 20      Segmented Neutrophils/Neutrophils          NEUTLE
# 21      Segmented Neutrophils/Neutrophils            NEUT
# 22           Hepatitis B Virus e Antibody          HEVVLD
# 23           Hepatitis B Virus e Antibody           HERNA
# 24    Hepatitis B Virus Core IgG Antibody          HEVVLD
# 25    Hepatitis B Virus Core IgG Antibody         HAABIGM
# 26                         HAV Viral Load          HEVVLD
# 27                         HAV Viral Load         PB19VLD
# 28              Hepatitis C Virus Antigen          HEVVLD
# 29              Hepatitis C Virus Antigen           HERNA
# ...                                   ...             ...
# 6498                                  NaN             NaN
# 6499                                  NaN             NaN
# 6500                                  NaN             NaN
# 6501                                  NaN             NaN
# 6502                                  NaN             NaN
# 6503                                  NaN             NaN
# 6504                                  NaN             NaN
# 6505                                  NaN             NaN
# 6506                                  NaN             NaN
# 6507                                  NaN             NaN
# 6508                                  NaN             NaN
# 6509                                  NaN             NaN
# 6510                                  NaN             NaN
# 6511                                  NaN             NaN
# 6512                                  NaN             NaN
# 6513                                  NaN             NaN
# 6514                                  NaN             NaN
# 6515                                  NaN             NaN
# 6516                                  NaN             NaN
# 6517                                  NaN             NaN
# 6518                                  NaN             NaN
# 6519                                  NaN             NaN
# 6520                                  NaN             NaN
# 6521                                  NaN             NaN
# 6522                                  NaN             NaN
# 6523                                  NaN             NaN
# 6524                                  NaN             NaN
# 6525                                  NaN             NaN
# 6526                                  NaN             NaN
# 6527                                  NaN             NaN
#
#                               a_LBTEST80-50 LBTESTCD - below50  \
# 0                    Hepatitis E Viral Load             HBVVLD
# 1                 Parvovirus B19 Viral Load             HBVVLD
# 2                          HHV-6 Viral Load             HBVVLD
# 3                    Hepatitis E Viral Load             HBVVLD
# 4                           Hepatitis E RNA             HBVVLD
# 5                    Lymphocytes/Leukocytes             HBVVLD
# 6                      Lymphocytes Atypical             HBVVLD
# 7            Hepatitis A Virus Antibody IgM             HBVVLD
# 8     Epstein-Barr Nuclear Antigen 1 IgG Ab             HBVVLD
# 9            Soluble Liver Antigen Antibody             HBVVLD
# 10                  Choriogonadotropin Beta             HBVVLD
# 11      HSV 1/2 IgM Antibody Interpretation             HBVVLD
# 12           Hepatitis A Virus Antibody IgM             HBVVLD
# 13                   Hepatitis E Viral Load             HBVVLD
# 14                          Hepatitis E RNA             HBVVLD
# 15           Hepatitis A Virus Antibody IgM             HBVVLD
# 16                                  Nitrite             HBVVLD
# 17                   Hepatitis E Viral Load             HBVVLD
# 18           Hepatitis A Virus Antibody IgM             HBVVLD
# 19                          Hepatitis E RNA             HBVVLD
# 20                   Neutrophils/Leukocytes             HBVVLD
# 21                              Neutrophils             HBVVLD
# 22                   Hepatitis E Viral Load             HBVVLD
# 23                          Hepatitis E RNA             HBVVLD
# 24                   Hepatitis E Viral Load             HBVVLD
# 25           Hepatitis A Virus Antibody IgM             HBVVLD
# 26                   Hepatitis E Viral Load             HBVVLD
# 27                Parvovirus B19 Viral Load             HBVVLD
# 28                   Hepatitis E Viral Load             HBVVLD
# 29                          Hepatitis E RNA             HBVVLD
# ...                                     ...                ...
# 6498                                    NaN             BASOCE
# 6499                                    NaN             BASOCE
# 6500                                    NaN             BASOCE
# 6501                                    NaN             BASOCE
# 6502                                    NaN             BASOCE
# 6503                                    NaN             BASOCE
# 6504                                    NaN             BASOCE
# 6505                                    NaN             BASOCE
# 6506                                    NaN             BASOCE
# 6507                                    NaN             BASOCE
# 6508                                    NaN             BASOCE
# 6509                                    NaN             BASOCE
# 6510                                    NaN             BASOCE
# 6511                                    NaN             BASOCE
# 6512                                    NaN             BASOCE
# 6513                                    NaN             BASOCE
# 6514                                    NaN             BASOCE
# 6515                                    NaN             BASOCE
# 6516                                    NaN             BASOCE
# 6517                                    NaN             BASOCE
# 6518                                    NaN             BASOCE
# 6519                                    NaN             BASOCE
# 6520                                    NaN             BASOCE
# 6521                                    NaN             BASOCE
# 6522                                    NaN             BASOCE
# 6523                                    NaN             BASOCE
# 6524                                    NaN             BASOCE
# 6525                                    NaN             BASOCE
# 6526                                    NaN             BASOCE
# 6527                                    NaN             BASOCE
#
#              LBTEST- below50 a_LBTESTCD- below50  \
# 0     HBV Viral Load (IU/mL)             KETONES
# 1     HBV Viral Load (IU/mL)              NEUTLE
# 2     HBV Viral Load (IU/mL)            SCSPMSR1
# 3     HBV Viral Load (IU/mL)                BACT
# 4     HBV Viral Load (IU/mL)            SCSPMSR2
# 5     HBV Viral Load (IU/mL)            FATBODOV
# 6     HBV Viral Load (IU/mL)            CYTRPHOS
# 7     HBV Viral Load (IU/mL)             CYCAOXA
# 8     HBV Viral Load (IU/mL)              SODIUM
# 9     HBV Viral Load (IU/mL)               GLOBG
# 10    HBV Viral Load (IU/mL)                MONO
# 11    HBV Viral Load (IU/mL)             GLOBBPT
# 12    HBV Viral Load (IU/mL)               GLOBB
# 13    HBV Viral Load (IU/mL)             PHENTHZ
# 14    HBV Viral Load (IU/mL)             CYCACAR
# 15    HBV Viral Load (IU/mL)            HS12GMAI
# 16    HBV Viral Load (IU/mL)               CSWAX
# 17    HBV Viral Load (IU/mL)            GLOBA2PT
# 18    HBV Viral Load (IU/mL)             EPITUCE
# 19    HBV Viral Load (IU/mL)            GLOBA1PT
# 20    HBV Viral Load (IU/mL)             RBCCLMP
# 21    HBV Viral Load (IU/mL)            GTTYIELD
# 22    HBV Viral Load (IU/mL)             NEUTBLE
# 23    HBV Viral Load (IU/mL)            GTYIELD1
# 24    HBV Viral Load (IU/mL)            GTYIELD2
# 25    HBV Viral Load (IU/mL)              EPITCE
# 26    HBV Viral Load (IU/mL)               NEUTB
# 27    HBV Viral Load (IU/mL)            CYCAPHOS
# 28    HBV Viral Load (IU/mL)              SLAGAB
# 29    HBV Viral Load (IU/mL)             EPISQCE
# ...                      ...                 ...
# 6498   Basophils/Total Cells            SCSPMSQ2
# 6499   Basophils/Total Cells              GTVOL2
# 6500   Basophils/Total Cells            YEASTHYP
# 6501   Basophils/Total Cells              GTVOL1
# 6502   Basophils/Total Cells              APPEAR
# 6503   Basophils/Total Cells              CYBILI
# 6504   Basophils/Total Cells               SPERM
# 6505   Basophils/Total Cells              GTHVOL
# 6506   Basophils/Total Cells              GLOBA2
# 6507   Basophils/Total Cells              GLOBA1
# 6508   Basophils/Total Cells            ANTIDPRS
# 6509   Basophils/Total Cells             HHV6VLD
# 6510   Basophils/Total Cells              CYLEUC
# 6511   Basophils/Total Cells            FERRITIN
# 6512   Basophils/Total Cells            SCSPMS1P
# 6513   Basophils/Total Cells               HERNA
# 6514   Basophils/Total Cells                 FAT
# 6515   Basophils/Total Cells             NITRITE
# 6516   Basophils/Total Cells            SCVZVTET
# 6517   Basophils/Total Cells              GTSVOL
# 6518   Basophils/Total Cells               TRICH
# 6519   Basophils/Total Cells            WBCCOVAL
# 6520   Basophils/Total Cells             SEDEXAM
# 6521   Basophils/Total Cells              OCCBLD
# 6522   Basophils/Total Cells            GTA280_1
# 6523   Basophils/Total Cells                 RBC
# 6524   Basophils/Total Cells               LYMAT
# 6525   Basophils/Total Cells                 MCH
# 6526   Basophils/Total Cells            GTCONCEN
# 6527   Basophils/Total Cells                 MCV
#
#                         a_LBTEST- below50
# 0                                 Ketones
# 1                  Neutrophils/Leukocytes
# 2                       SPE M-spike Reg.1
# 3                                Bacteria
# 4                       SPE M-spike Reg.2
# 5                        Fat Bodies, Oval
# 6               Triple Phosphate Crystals
# 7                Calcium Oxalate Crystals
# 8                                  Sodium
# 9                          Gamma Globulin
# 10                              Monocytes
# 11            Beta Globulin/Total Protein
# 12                          Beta Globulin
# 13                          Phenothiazine
# 14             Calcium Carbonate Crystals
# 15    HSV 1/2 IgM Antibody Interpretation
# 16                             Waxy Casts
# 17         Alpha-2 Globulin/Total Protein
# 18               Tubular Epithelial Cells
# 19         Alpha-1 Globulin/Total Protein
# 20                Erythrocyte Cell Clumps
# 21                            Total Yield
# 22       Neutrophils Band Form/Leukocytes
# 23                        Aliquot 1 Yield
# 24                        Aliquot 2 Yield
# 25          Transitional Epithelial Cells
# 26                  Neutrophils Band Form
# 27             Calcium Phosphate Crystals
# 28         Soluble Liver Antigen Antibody
# 29              Squamous Epithelial Cells
# ...                                   ...
# 6498                    SPE M-spike Qty 2
# 6499             Aliquot Volume in Tube 2
# 6500                         Yeast Hyphae
# 6501             Aliquot Volume in Tube 1
# 6502                  Specimen Appearance
# 6503                   Bilirubin Crystals
# 6504                          Spermatozoa
# 6505                     Hydration Volume
# 6506                     Alpha-2 Globulin
# 6507                     Alpha-1 Globulin
# 6508                      Antidepressants
# 6509                     HHV-6 Viral Load
# 6510                     Leucine Crystals
# 6511                             Ferritin
# 6512               SPE-M-spike 1 -Percent
# 6513                      Hepatitis E RNA
# 6514                                  Fat
# 6515                              Nitrite
# 6516            VZV Tot(ACIF) Endpt Titer
# 6517                        Sample Volume
# 6518                          Trichomonas
# 6519                         WBC Comments
# 6520                 Sediment Examination
# 6521                         Occult Blood
# 6522                                 A280
# 6523                         Erythrocytes
# 6524                 Lymphocytes Atypical
# 6525     Ery. Mean Corpuscular Hemoglobin
# 6526                        Concentration
# 6527         Ery. Mean Corpuscular Volume
#
# [6528 rows x 12 columns]

# %%
result.to_csv("C:/Users/Md.Shamsuzzaman/Documents/OCS/AIH/Daclizumab/similar LBTESTCD.csv", index = False)

# %%
for k,v in unique_req_lbtest.items():
    print v,'\t\t','\t\t',k
# Out:
# HBV Viral Load (IU/mL) 				HBVVLD
# Hepatitis B Virus Antibody 				HBAB
# Lymphotactin 				LYMPHOTC
# HCV Genotype 				HCVGTYPE
# HIV Antibody 				HIVAB
# Epstein-Barr Capsid IgM Antibody 				EBCIGMAB
# Smooth Muscle IgG Antibody 				SMUSCGAB
# Interferon Beta 				IFNB
#
# HIV-1/2 Antibody 				HIV12AB
# Varicella Zoster Virus Antibody 				VZVAB
# Hepatitis E Virus Antibody 				HEAB
# Varicella Zoster Virus IgA Antibody 				VZVIGAAB
# Urea Nitrogen 				UREAN
# HBV Genotype 				HBVGTYPE
# Hepatitis B Virus e Antigen 				HBEAG
# Segmented Neutrophils/Neutrophils 				NEUTSGNE
# HBV DNA PCR Taq Man 				HBDTQM
# Hepatitis B Virus e Antibody 				HBEAB
# Hepatitis B Virus Core IgG Antibody 				HBCIGGAB
# HCV RNA Taq 2.0-Exp 				HCRTQE
# Fibrosis Score 				FBTSTSCR
# HAV Viral Load 				HAVVLD
# Prothrombin Intl. Normalized Ratio 				INR
# Hepatitis C Virus Antigen 				HCAG
# HIV Viral Load 				HIVVLD
# Liver Kidney Microsomal Type 1 IgA Ab 				LKM1IAAB
# Hepatitis D Virus Antibody 				HDAB
# Monoclonal Protein Spike 				MSPIKE
# Anti-Neutrophil Cytoplasmic Antibody 				ANCAB
# Herpes Simplex Virus 2 IgM Antibody 				HS2IGMAB
# EBV Viral Load 				EBVVLD
# Hepatitis A Virus IgM Antibody 				HAIGMAB
# HIV-2 Antibody 				HIV2AB
# Lymphocytes/Total Cells 				LYMCE
# Calcium  				CA
# Fibrosis Stage 				FBTSTSTG
# Creatinine Clearance (mL/min) 				CREATCLR
# CMV Viral Load 				CMVVLD
# HBV Viral Load - Diluted (IU/mL) 				HBVVLDD
# Liver Kidney Microsomal Type 1 IgM Ab 				LKM1IMAB
# HIV-1 Antibody 				HIV1AB
# Immunoglobulin A 				IGA
# Amylase (U/L) 				AMYLASE
# Acetaminophen 				ACTMN
# Immunoglobulin M  				IGM
# Triacylglycerol Lipase (U/L) 				LIPASET
# Herpes Sim.Virus 1/2 IgM Interpretation 				HIGMIN
# Herpes Simplex Virus 6 Antibody 				HS6AB
# Hepatitis D Virus IgM Antibody 				HDIGMAB
# Soluble Liver Antigen IgG Antibody 				SLAIGGAB
# Lymphocytes Activated  				LYMA
# HSV-1/2 IgG Ab;Herpes Simplex Virus 1/2 IgG Antibody 				HS12GGAB
# Eosinophils/Total Cells 				EOSCE
# Hepatitis E Virus RNA 				HEVRNA
# LKM-1;Liver Kidney Microsomal Type 1 Antibody 				LKM1AB
# Herpes Simplex Virus 1 IgM Antibody 				HS1IGMAB
# Herpes Sim.Virus 1/2 IgM IFA Confirm 				HIGMC
# HDV Viral Load 				HDVVLD
# Hepatitis D Virus IgG Antibody 				HDIGGAB
# HBV DNA Combined with Diluted (IU/mL) 				HBVDNA
# Epstein-Barr Capsid IgG Antibody 				EBCIGGAB
# Basophils/Total Cells 				BASOCE

# %%
for k1,v1 in unique_dac_lbtest.items():
        
    print v1,'\t\t',k1
# Out:
# Ketones 		KETONES
# Neutrophils/Leukocytes 		NEUTLE
# SPE M-spike Reg.1 		SCSPMSR1
# Bacteria 		BACT
# SPE M-spike Reg.2 		SCSPMSR2
# Fat Bodies, Oval 		FATBODOV
# Triple Phosphate Crystals 		CYTRPHOS
# Calcium Oxalate Crystals 		CYCAOXA
# Sodium 		SODIUM
# Gamma Globulin 		GLOBG
# Monocytes 		MONO
# Beta Globulin/Total Protein 		GLOBBPT
# Beta Globulin 		GLOBB
# Phenothiazine 		PHENTHZ
# Calcium Carbonate Crystals 		CYCACAR
# HSV 1/2 IgM Antibody Interpretation 		HS12GMAI
# Waxy Casts 		CSWAX
# Alpha-2 Globulin/Total Protein 		GLOBA2PT
# Tubular Epithelial Cells 		EPITUCE
# Hepatitis E Viral Load 		HEVVLD
# Alpha-1 Globulin/Total Protein 		GLOBA1PT
# Erythrocyte Cell Clumps 		RBCCLMP
# Total Yield 		GTTYIELD
# Neutrophils Band Form/Leukocytes 		NEUTBLE
# Aliquot 1 Yield 		GTYIELD1
# Aliquot 2 Yield 		GTYIELD2
# Transitional Epithelial Cells 		EPITCE
# Neutrophils Band Form 		NEUTB
# Calcium Phosphate Crystals 		CYCAPHOS
# Soluble Liver Antigen Antibody 		SLAGAB
# Squamous Epithelial Cells 		EPISQCE
# Parvovirus B19 Viral Load 		PB19VLD
# Methaqualone 		METHQLDN
# Epstein-Barr Capsid IgM Antigen 		EBCIGMAG
# Lymphocytes Atypical/Leukocytes 		LYMATLE
# Metamyelocytes/Leukocytes 		METAMYLE
# Neutrophils, Segmented/Leukocytes 		NEUTSGLE
# A260 		GTA260_1
# Color 		COLOR
# Cystine Crystals 		CYCYSTIN
# Blood Urea Nitrogen 		BUN
# Myelocytes 		MYCY
# Leukocyte Cell Clumps 		WBCCLMP
# pH 		PH
# Epstein-Barr Nuclear Antigen 1 IgG Ab 		EBN1IGAB
# Potassium 		K
# SPE-M-spike 2 -Percent 		SCSPMS2P
# Choriogonadotropin Beta 		HCG
# Gamma Globulin/Total Protein 		GLOBGPT
# Lymphocytes/Leukocytes 		LYMLE
# Aliquot 1 Concentration 		GTCONCN1
# Aliquot 2 Concentration 		GTCONCN2
# Ery. Mean Corpuscular HGB Concentration 		MCHC
# Ammonium Biurate Crystals 		CYAMMBIU
# VZV IgM-Endpt Titer 		SCVZIGMT
# Metamyelocytes 		METAMY
# Purity 		GTPURITY
# Mucous Threads 		MUCTHR
# Erythrocyte Cell Morphology 		RBCMORPH
# Neutrophils 		NEUT
# Eosinophils/Leukocytes 		EOSLE
# Monocytes/Leukocytes 		MONOLE
# Yeast Budding 		YEASTBUD
# Hyaline Casts 		CSHYAL
# Tyrosine Crystals 		CYTYRO
# Leukocyte Esterase 		LEUKASE
# Hepatitis A Virus Antibody IgM 		HAABIGM
# Acetaminophen 		APAP
# Uric Acid Crystals 		CYURIAC
# VZV Profile Interpretation 		VZVINTP
# Amorphous Crystals 		CYAMORPH
# Granular Casts 		CSGRAN
# Specific Gravity 		SPGRAV
# Myelocytes/Leukocytes 		MYCYLE
# Basophils/Leukocytes 		BASOLE
# Albumin/Total Protein 		ALBPROT
# SPE M-spike Qty 1 		SCSPMSQ1
# SPE M-spike Qty 2 		SCSPMSQ2
# Aliquot Volume in Tube 2 		GTVOL2
# Yeast Hyphae 		YEASTHYP
# Aliquot Volume in Tube 1 		GTVOL1
# Specimen Appearance 		APPEAR
# Bilirubin Crystals 		CYBILI
# Spermatozoa 		SPERM
# Hydration Volume 		GTHVOL
# Alpha-2 Globulin 		GLOBA2
# Alpha-1 Globulin 		GLOBA1
# Antidepressants 		ANTIDPRS
# HHV-6 Viral Load 		HHV6VLD
# Leucine Crystals 		CYLEUC
# Ferritin 		FERRITIN
# SPE-M-spike 1 -Percent 		SCSPMS1P
# Hepatitis E RNA 		HERNA
# Fat 		FAT
# Nitrite 		NITRITE
# VZV Tot(ACIF) Endpt Titer 		SCVZVTET
# Sample Volume 		GTSVOL
# Trichomonas 		TRICH
# WBC Comments 		WBCCOVAL
# Sediment Examination 		SEDEXAM
# Occult Blood 		OCCBLD
# A280 		GTA280_1
# Erythrocytes 		RBC
# Lymphocytes Atypical 		LYMAT
# Ery. Mean Corpuscular Hemoglobin 		MCH
# Concentration 		GTCONCEN
# Ery. Mean Corpuscular Volume 		MCV

# %%
# Dict to replace the LBTESTCD with
matched_LBTESTCD = {'UREAN':'BUN', 'HAIGMAB':'HAABIGM', 'ACTMN':'APAP','HIGMIN':'HS12GMAI', 'SLAIGGAB':'SLAGAB','HEVRNA':'HERNA'}

# %%
# Replace non SDTM LBTSTCDs with SDTM LBTSTCDs
for k, v in matched_LBTESTCD.items():
    lb_df.loc[lb_df.LBTESTCD == v] = k

# %%
lb_df.to_csv("C:/Users/Md.Shamsuzzaman/Documents/OCS/AIH/Daclizumab/205MS301_lb.csv",index = False)

# %%
lb_df1 = lb_df

# %%
# Importing phase 2 LB data into pandas data frame
df_dac = pd.read_sas(r'\\cdsesub1\\evsprod\\BLA761029\\0014\\m5\\datasets\\205MS201\\tabulations\\sdtm\\lb.xpt')

# %%
df_dac.iloc[:,:15].head()
# Out:
#     STUDYID DOMAIN           USUBJID  LBSEQ  LBREFID LBTESTCD  \
# 0  205MS201     LB  205MS201/100-001    1.0  L721053      ALP
# 1  205MS201     LB  205MS201/100-001    2.0  L721053      ALT
# 2  205MS201     LB  205MS201/100-001    3.0  L721053      AST
# 3  205MS201     LB  205MS201/100-001    4.0  L721053   BICARB
# 4  205MS201     LB  205MS201/100-001    5.0  L721053      BUN
#
#                        LBTEST            LBCAT LBSCAT LBORRES LBORRESU  \
# 0        Alkaline Phosphatase  BLOOD CHEMISTRY             62      U/L
# 1    Alanine Aminotransferase  BLOOD CHEMISTRY             18      U/L
# 2  Aspartate Aminotransferase  BLOOD CHEMISTRY             14      U/L
# 3                 Bicarbonate  BLOOD CHEMISTRY           25.1   mmol/L
# 4         Blood Urea Nitrogen  BLOOD CHEMISTRY            3.0   mmol/L
#
#   LBORNRLO LBORNRHI LBSTRESC  LBSTRESN
# 0       31      106       62      62.0
# 1        6       34       18      18.0
# 2        9       34       14      14.0
# 3       17     30.6     25.1      25.1
# 4      1.4      8.6        3       3.0

# %%
# find common col var 
common_var = list(set(LB_data_elements).intersection(list(df_dac)))

# %%
# find the vars which are present in lb_df and missing in df_dac
list(set(LB_data_elements) - set(common_var))
# Out:
# [u'APPLICID', u'LBTOX', u'LBENDTC', u'LBFAST', u'LBSTNRC']

# %%
# find the vars which are missing in df_dac
list(set(list(df_dac)) - set(common_var))
# Out:
# [u'LBORRES',
#  u'LBORRESU',
#  u'LBORNRHI',
#  u'LBSCAT',
#  u'EPOCH',
#  u'LBREFID',
#  u'LBNAM',
#  u'LBORNRLO',
#  u'LBNRIND']

# %%
# fill up the dm_df with daclizumab data
lb_df['APPLICID'] = 'BLA761029'
lb_df[common_var] = df_dac[common_var]

# %%
# Check the LBTEST code values
dac_cd = set(list(lb_df['LBTESTCD']))

# %%
# find common col var 
common_var = list(set(req_code).intersection(list(dac_cd)))

# %%
# find the code which are missing in dac_cd
unique_req_cd = list(set(req_code) - set(common_var))

# %%
unique_req_cd
# Out:
# [u'HBVVLD',
#  u'LKM1IGAB',
#  u'BARB',
#  u'CMVIGMAB',
#  u'HBVGTYPE',
#  u'NEUTSGNE',
#  u'FBTSTSCR',
#  u'HCAG',
#  u'HBDNA',
#  u'COCAINE',
#  u'HS1IGMAB',
#  u'HS12GMAB',
#  u'CREATCLR',
#  u'HEIGGAB',
#  u'TRCYANDP',
#  u'HDIGMAB',
#  u'HIV12AB',
#  u'EBCIGGAB',
#  u'EBVINTP',
#  u'CRLPLSMN',
#  u'PCP',
#  u'HIVAB',
#  u'EBCIGMAB',
#  u'HS1IGGAB',
#  u'VZVAB',
#  u'HEAB',
#  u'UREAN',
#  u'HIGMIN',
#  u'MSPIKE',
#  u'AMA',
#  u'HDIGGAB',
#  u'PROPOX',
#  u'HDAB',
#  u'CMVIGGAB',
#  u'HS2IGMAB',
#  u'FBTSTSTG',
#  u'HS6AB',
#  u'HCVVLD',
#  u'IGG',
#  u'HCRTQE',
#  u'IGE',
#  u'IGA',
#  u'IGM',
#  u'LIPASET',
#  u'HBDTQM',
#  u'SLAIGGAB',
#  u'OPIATE',
#  u'HS12GGAB',
#  u'EOSCE',
#  u'HBCIGMAB',
#  u'HBVDNA',
#  u'BNZDZPN',
#  u'HCVGTYPE',
#  u'IFNB\n',
#  u'HAAB',
#  u'HS2IGGAB',
#  u'VZVIGMAB',
#  u'HBCIGGAB',
#  u'CANNAB',
#  u'HIVVLD',
#  u'ANCAB',
#  u'HBSAB',
#  u'HIV2AB',
#  u'CMVVLD',
#  u'PB19GMAB',
#  u'LKM1IMAB',
#  u'ANA',
#  u'LYMA',
#  u'METHDN',
#  u'VZVIGGAB',
#  u'HIGMC',
#  u'HDVVLD',
#  u'AMPHET',
#  u'BASOCE',
#  u'SMUSCGAB',
#  u'INR',
#  u'HBEAG',
#  u'HBEAB',
#  u'HEIGMAB',
#  u'HBAB',
#  u'HAVVLD',
#  u'HAIGMAB',
#  u'LYMCE',
#  u'EBVVLD',
#  u'LKM1IAAB',
#  u'HBVVLDD',
#  u'HIV1AB',
#  u'ACTMN',
#  u'VZVIGAAB',
#  u'LYMPHOTC',
#  u'EBNAB',
#  u'PB19GGAB',
#  u'HEVRNA',
#  u'LKM1AB',
#  u'SMUSCAB']

# %%
# find the code which are missing in req_code
unique_dac_cd = list(set(dac_cd) - set(common_var))

# %%
df_dac_unique = df_dac.drop_duplicates(['LBTESTCD'], keep = 'first')

# %%
# req_code df with unique req code 
unique_df_code = df_code[df_code.LBTESTCD.isin(unique_req_cd)]

# %%
#dac_df with unique dac_code 
df_dac_unique = df_dac_unique[df_dac_unique.LBTESTCD.isin(unique_dac_cd)]

# %%
# dac_df dictionary with unique LBTEST and LBTESTCD
unique_dac_lbtest = dict(zip(df_dac_unique.LBTESTCD,df_dac_unique.LBTEST))

# %%
# req_code_df dictionary with unique LBTEST and LBTESTCD
unique_req_lbtest = dict(zip(unique_df_code.LBTESTCD,unique_df_code.LBTEST))

# %%
for k,v in unique_req_lbtest.items():
    for k1,v1 in unique_dac_lbtest.items():
        if difflib.SequenceMatcher(None,v,v1).ratio() >=0.7 :
            print v,'\t\t',v1,'\t\t',k,'\t\t',k1

# %%
# Dict to replace the LBTESTCD with
matched_LBTESTCD = {'UREAN':'BUN', 'LIPASET':'LIPASE'}

# %%
# Replace non SDTM LBTSTCDs with SDTM LBTSTCDs
for k, v in matched_LBTESTCD.items():
    lb_df.loc[lb_df.LBTESTCD == v] = k

# %%
lb_df.to_csv("C:/Users/Md.Shamsuzzaman/Documents/OCS/AIH/Daclizumab/205MS201_lb.csv",index = False)

# %%
unique_dac_lbtest = {}

for val in unique_dac_cd:
    unique_dac_lbtest[val] = df_dac_unique[df_dac_unique.LBTESTCD == val].LBTEST

# %%
unique_req_lbtest = {}
for val in unique_req_cd:
    unique_req_lbtest[val] = df_code.ix[df_code.LBTESTCD == val, 'LBTEST'].values
    #print df_code.ix[df_code.LBTESTCD == val, 'LBTEST'].value
#d = dict((df_code[df_code.LBTESTCD == x].LBTEST,x)

# %%
len(set(unique_dac_lbtest))

# %%
df_dac_unique.head()

# %%
df_dac_unique

# %%
# find common col var 
common_var = list(set(DM_data_elements).intersection(list(df_tenofovir)))

# %%
#how many are common
len(common_var)

# %%
# extract the cocmmon variable data from tenofovir data frame
ndf4 =df_tenofovir[common_var]

# %%
len(ndf2)

# %%
len(ndf4)

# %%
len(ndf3)

# %%
len(ndf1)

# %%
len(ndf)

# %%
# Importing data from daclizumab into pandas data frame
df_daclizumab = pandas.read_sas(r"\\cdsesub1\evsprod\BLA761029\0000\m5\datasets\205ms301\tabulations\sdtm\dm.xpt")

# %%
df_daclizumab.info()

# %%
df_daclizumab.head()

# %%
# find common col var 
common_var = list(set(DM_data_elements).intersection(list(df_daclizumab)))

# %%
#how many are common
len(common_var)

# %%
# Not all 20 are present in daclizumab DM domain. Hence, create an empty df with variables needed first

ddf = pd.DataFrame(index = range(len(df_daclizumab)), columns = DM_data_elements)

# %%
# extract the cocmmon variable data from tenofovir data frame
ddf =df_daclizumab[common_var]

# %%
# merge the tenofovir and daclizumab dfs
fdf = ndf.append(ddf).reset_index()

# %%
fdf.info()

# %%
fdf = fdf.drop('index',1)

# %%
fdf.info()

# %%
fdf.to_csv("extracted_dataset.csv", encoding='utf-8')
